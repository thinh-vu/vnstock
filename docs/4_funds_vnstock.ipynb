# %% [markdown]
# <p>
#   <a href="https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/4_funds_vnstock.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://codespaces.new/thinh-vu/vnstock" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
# </p>

# %% [markdown]
# ## Khởi tạo đối tượng

# %%
# !pip install vnstock

# %%
# Gọi từ core module
from vnstock import Fund
fund = Fund()

# # Gọi từ Vnstock wrapper module - version 3.0.7
# from vnstock import Vnstock
# fund = Vnstock().fund()
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 57

# %% [markdown]
# ## Liệt kê danh sách các quỹ

# %%
fund.listing().head()
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 57
#   short_name                                        name     fund_type  \
# 0       DCDS         QUỸ ĐẦU TƯ CHỨNG KHOÁN NĂNG ĐỘNG DC  Quỹ cổ phiếu
# 1     SSISCA  QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI  Quỹ cổ phiếu
# 2       MBVF               QUỸ ĐẦU TƯ GIÁ TRỊ MB CAPITAL  Quỹ cổ phiếu
# 3   VCBF-MGF        QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG VCBF  Quỹ cổ phiếu
# 4   VCBF-BCF           QUỸ ĐẦU TƯ CỔ PHIẾU HÀNG ĐẦU VCBF  Quỹ cổ phiếu
#
#                                      fund_owner_name  management_fee  \
# 0  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ DRAGON CAPITAL VIỆ...            1.95
# 1                       CÔNG TY TNHH QUẢN LÝ QUỸ SSI            1.75
# 2              CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ ĐẦU TƯ MB            1.50
# 3  CÔNG TY TNHH QUẢN LÝ QUỸ ĐẦU TƯ CHỨNG KHOÁN VI...            1.90
# 4  CÔNG TY TNHH QUẢN LÝ QUỸ ĐẦU TƯ CHỨNG KHOÁN VI...            1.90
#
# ...

# %% [markdown]
# ## Tìm kiếm quỹ theo tên viết tắt

# %%
# Nhập 1 phần tên viết tắt để lọc
fund.filter('DC')
# Out:
#    id shortName
# 0  40     VNDCF
# 1  67      DCIP
# 2  62    HDBOND
# 3  27      DCBF
# 4  25      DCDE
# 5  28      DCDS
# 6  29      DCAF

# %% [markdown]
# ## Thông tin chi tiết quỹ

# %% [markdown]
# ### Tăng trưởng NAV

# %%
fund.details.nav_report('SSISCA')
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#             date  nav_per_unit short_name
# 0     2017-01-04      14412.31     SSISCA
# 1     2017-01-11      14527.86     SSISCA
# 2     2017-01-18      14240.04     SSISCA
# 3     2017-01-25      14547.21     SSISCA
# 4     2017-01-31      14541.96     SSISCA
# ...          ...           ...        ...
# 1801  2025-07-28      43350.06     SSISCA
# 1802  2025-07-29      43720.10     SSISCA
# 1803  2025-07-30      42085.80     SSISCA
# 1804  2025-07-31      42643.05     SSISCA
# 1805  2025-08-01      42466.33     SSISCA
#
# [1806 rows x 3 columns]

# %% [markdown]
# ### Danh mục đầu tư lớn (top 10)

# %%
fund.details.top_holding('SSISCA')
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#   stock_code                industry  net_asset_percent type_asset  \
# 0        TCB               Ngân hàng               7.85      STOCK
# 1        CTG               Ngân hàng               6.93      STOCK
# 2        MBB               Ngân hàng               6.90      STOCK
# 3        STB               Ngân hàng               5.11      STOCK
# 4        FPT  Công nghệ và thông tin               5.05      STOCK
# 5        HPG       Vật liệu xây dựng               4.93      STOCK
# 6        MWG                  Bán lẻ               4.80      STOCK
# 7        REE           Thiết bị điện               4.71      STOCK
# 8        ACB               Ngân hàng               4.64      STOCK
# 9        VCB               Ngân hàng               4.15      STOCK
#
#     update_at  fundId short_name
# 0  2025-07-04      11     SSISCA
# 1  2025-07-04      11     SSISCA
# 2  2025-07-04      11     SSISCA
# ...

# %% [markdown]
# ### Phân bổ theo ngành (Top 10)

# %%
fund.details.industry_holding('SSISCA')
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#                       industry  net_asset_percent short_name
# 0                    Ngân hàng              35.58     SSISCA
# 1                 Bất động sản              12.61     SSISCA
# 2       Công nghệ và thông tin               5.05     SSISCA
# 3            Vật liệu xây dựng               4.93     SSISCA
# 4                       Bán lẻ               4.80     SSISCA
# 5                Thiết bị điện               4.71     SSISCA
# 6   Sản xuất Thiết bị, máy móc               3.64     SSISCA
# 7             Sản xuất Phụ trợ               3.57     SSISCA
# 8     Sản xuất Nhựa - Hóa chất               3.39     SSISCA
# 9          Thực phẩm - Đồ uống               2.96     SSISCA
# 10                 Chứng khoán               2.88     SSISCA
# 11                    Tiện ích               2.73     SSISCA
# 12                 Khai khoáng               2.39     SSISCA
# ...

# %% [markdown]
# ### Phân bổ theo tài sản

# %%
fund.details.asset_holding('SSISCA')
# Out:
# 2025-08-03 23:31:02 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#    asset_percent                asset_type short_name
# 0           91.6                  Cổ phiếu     SSISCA
# 1            8.4  Tiền và tương đương tiền     SSISCA
