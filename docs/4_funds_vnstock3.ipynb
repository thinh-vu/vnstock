# %%
# %cd "/Users/mrthinh/Library/CloudStorage/OneDrive-Personal/Github/vnstock"
# Out:
# /Users/mrthinh/Library/CloudStorage/OneDrive-Personal/Github/vnstock
# /Users/mrthinh/Library/Python/3.10/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from vnstock3.explorer.fmarket.fund import Fund
fund = Fund()
# Out:
# Total number of funds currently listed on Fmarket:  49

# %%
fund.listing().head()
# Out:
# Total number of funds currently listed on Fmarket:  49
#   short_name                                               name  \
# 0     SSISCA         QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI
# 1      VESAF  QUỸ ĐẦU TƯ CỔ PHIẾU TIẾP CẬN THỊ TRƯỜNG VINACA...
# 2       BVPF            QUỸ ĐẦU TƯ CỔ PHIẾU TRIỂN VỌNG BẢO VIỆT
# 3       VEOF         QUỸ ĐẦU TƯ CỔ PHIẾU HƯNG THỊNH VINACAPITAL
# 4        VFF        QUỸ ĐẦU TƯ TRÁI PHIẾU BẢO THỊNH VINACAPITAL
#
#         fund_type                          fund_owner_name  management_fee  \
# 0    Quỹ cổ phiếu             CÔNG TY TNHH QUẢN LÝ QUỸ SSI            1.75
# 1    Quỹ cổ phiếu  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ VINACAPITAL            1.75
# 2    Quỹ cổ phiếu        CÔNG TY TNHH QUẢN LÝ QUỸ BẢO VIỆT            1.50
# 3    Quỹ cổ phiếu  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ VINACAPITAL            1.75
# 4  Quỹ trái phiếu  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ VINACAPITAL            0.95
#
#   inception_date       nav  nav_change_previous  nav_change_last_year  \
# ...

# %%
fund.details('UVDIF', section='industry_holding')
# Out:
# Retrieving data for UVDIF
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fund.details('UVDIF', section='industry_holding')
#
# File ~/Library/CloudStorage/OneDrive-Personal/Github/vnstock/vnstock3/explorer/fmarket/fund.py:151, in Fund.details(self, symbol, section)
#     142 section_mapping = {
#     143     "top_holding": self.top_holding,
#     144     "industry_holding": self.industry_holding,
#     145     "nav_report": self.nav_report,
#     146     "asset_holding": self.asset_holding,
#     147 }
#     149 if section in section_mapping:
#     150     # Match with appropriate function
# --> 151     df = section_mapping[section](fundId=fundID)
#     152     df["short_name"] = symbol
#     153     return df
#
# ...

# %%
fund.filter('SSISCA')
# Out:
#    id shortName
# 0  11    SSISCA

# %%
fund.top_holding().head()
# Out:
#   stock_code                industry  net_asset_percent type_asset  \
# 0        FPT  Công nghệ và thông tin              16.52      STOCK
# 1        MBB               Ngân hàng               9.35      STOCK
# 2        MWG                  Bán lẻ               4.65      STOCK
# 3        PTB        Sản xuất Phụ trợ               4.59      STOCK
# 4        PVS             Khai khoáng               3.83      STOCK
#
#     update_at  fundId
# 0  2024-07-05      23
# 1  2024-07-05      23
# 2  2024-07-05      23
# 3  2024-07-05      23
# 4  2024-07-05      23

# %%
fund.industry_holding()
# Out:
#                     industry  net_asset_percent
# 0     Công nghệ và thông tin              16.52
# 1                  Ngân hàng              15.30
# 2           Sản xuất Phụ trợ               9.60
# 3               Bất động sản               9.32
# 4          Vận tải - Kho bãi               8.65
# 5                Chứng khoán               6.01
# 6                Khai khoáng               5.98
# 7                     Bán lẻ               4.65
# 8          Chế biến thủy sản               3.79
# 9   Sản xuất Nhựa - Hóa chất               3.59
# 10       Thực phẩm - Đồ uống               3.57
# 11                  Xây dựng               3.11

# %%
fund.nav_report()
# Out:
#            date  nav_per_unit
# 0    2017-04-25      10000.00
# 1    2017-04-29      10058.00
# 2    2017-05-09      10093.00
# 3    2017-05-16      10165.00
# 4    2017-05-23      10254.00
# ..          ...           ...
# 957  2024-07-02      30736.89
# 958  2024-07-03      30931.12
# 959  2024-07-04      31109.19
# 960  2024-07-05      31296.52
# 961  2024-07-08      31457.86
#
# [962 rows x 2 columns]

# %%
fund.asset_holding()
# Out:
#    asset_percent                asset_type
# 0          90.06                  Cổ phiếu
# 1           9.94  Tiền và tương đương tiền
