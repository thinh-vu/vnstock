# %% [markdown]
# # Unified UI - Reference Layer (Lớp Dữ Liệu Tham Chiếu)
#
# Notebook này minh hoạ cơ chế truy xuất toàn bộ các phương thức thuộc Reference Domain, ánh xạ chuẩn theo tài liệu chính thức. Lớp Reference cung cấp dữ liệu nền tảng tĩnh, hiếm khi thay đổi theo realtime (ví dụ: thông tin công ty, danh sách mã cổ phiếu/chỉ số, lịch sự kiện, thông tin quỹ, v.v.).
#
# <p>
#   <a href="https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/unified-ui/01_Reference.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://codespaces.new/thinh-vu/vnstock" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
# </p>
#
#
# ---
#
# ### Sử dụng với Jupyter Notebook (Trong IDE)
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# <details>
# <summary><b>💡 <i>Click để xem hướng dẫn thiết lập chi tiết</i></b></summary>
# <br>
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# **1. Kích hoạt môi trường ảo**
# (Mặc định do Vnstock Installer tạo ra, bạn có thể chỉnh lại path nếu cài ở vị trí khác)
# ```bash
# # macOS / Linux
# source ~/.venv/bin/activate
# # Windows
# ~\.venv\Scripts\activate
# ```
#
# 2. Cài đặt thư viện kết nối (ipykernel)
#
# ```bash
# python -m pip install ipykernel
# ```
#
# 3. Đăng ký Kernel với Jupyter
#
# ```bash
# python -m ipykernel install --user --name=vnstock-venv --display-name "Python (Vnstock)"
# ```
#
# 4. Chọn Kernel trong IDE
#
# Nhìn góc trên bên phải Notebook, click vào tên Kernel hiện tại (vd: Select Kernel hoặc Python 3.x.x).
# Chọn Python (Vnstock) từ danh sách. (Tải lại cửa sổ nếu chưa thấy bằng tổ hợp phím `Ctrl`/`Cmd` + `Shift` + `P` sau đó tìm lệnh `Developer: Reload Window`).

# %% [markdown]
# ### Khởi động

# %%
from vnstock import Reference
from IPython.display import display

# Initialize Reference layer
ref = Reference()

# %% [markdown]
# ### 1. Company Domain (Thông Tin Công Ty)
#
# Cung cấp hồ sơ doanh nghiệp, ban lãnh đạo, cổ đông lớn, công ty con, sự kiện và biên lợi nhuận (margin).

# %% [markdown]
# **Thông tin công ty (Company Info)**

# %%
df = ref.company('TCB').info()
df.head()
# Out:
#   symbol                                             name sector  \
# 0    TCB  Ngân hàng Thương mại Cổ phần Kỹ thương Việt Nam  Banks
#
#                                              profile         listing_date  \
# 0  Ngân hàng Thương mại Cổ phần Kỹ thương Việt Na...  2018-06-04T00:00:00
#
#    issued_share
# 0  7.086240e+09

# %% [markdown]
# **Danh sách cổ đông lớn (Major Shareholders)**

# %%
df = ref.company('VIC').shareholders()
df.head()
# Out:
#   symbol                                               name  total_shares  \
# 0    VIC           Công ty Cổ Phần Tập Đoàn Đầu Tư Việt Nam    2520265316
# 1    VIC  Công ty Cổ phần Đầu tư và Phát triển Đường sắt...     834212369
# 2    VIC                                    Phạm Nhật Vượng     703848781
# 3    VIC                                     Phạm Thu Hương     341221050
# 4    VIC               Công ty Cổ phần Năng lượng Vinenergo     331412806
#
#       rate                     date
# 0  0.32590    2026-03-23T15:53:11.3
# 1  0.10787  2025-12-31T17:16:03.047
# 2  0.09101  2025-12-31T17:18:09.503
# 3  0.04428  2026-02-02T16:12:13.047
# 4  0.04300  2026-02-02T16:10:09.397

# %% [markdown]
# **Ban lãnh đạo / Quản lý cấp cao (Officers)**

# %%
df = ref.company('HPG').officers()
df.head()
# Out:
#   symbol               name                        position  total_shares  \
# 0    HPG     Trần Đình Long      Chủ tịch Hội đồng Quản trị    1980000000
# 3    HPG    Trần Tuấn Dương  Phó Chủ tịch Hội đồng Quản trị     177556764
# 4    HPG   Nguyễn Mạnh Tuấn  Phó Chủ tịch Hội đồng Quản trị     174088076
# 5    HPG  Nguyễn Ngọc Quang    Thành viên Hội đồng Quản trị     125485714
# 7    HPG     Doãn Gia Cường  Phó Chủ tịch Hội đồng Quản trị      96209794
#
#        rate
# 0  0.257960
# 3  0.023133
# 4  0.022700
# 5  0.016300
# 7  0.012500

# %% [markdown]
# **Danh sách công ty con (Subsidiaries)**

# %%
df = ref.company('VNM').subsidiaries()
df.head()
# Out:
#   symbol                                          name    rate sub_symbol
# 0    VNM          Driftwood Dairy Holdings Corporation  1.0000     DRIFTW
# 1    VNM                Angkor Dairy Products Co., Ltd  1.0000   ANGKORDP
# 2    VNM  Công ty TNHH MTV Bò Sữa Thống Nhất Thanh Hoá  1.0000     TNTHCM
# 3    VNM              Công ty TNHH MTV Bò Sữa Việt Nam  1.0000       VNMC
# 4    VNM    Lao-Jagro Development Xiengkhouang Co.,ltd  0.9207   LAOJAGRO

# %% [markdown]
# **Tin tức công ty (Company News)**

# %%
df = ref.company('TCB').news()
df.head()
# Out:
#                          id   news_id  language news_category_code icb_code  \
# 0  69effdf0db487120c6898099  11987420         0               None     None
# 1  69effdf0db487120c6897f82  11987172         0               None     None
# 2  69ed5b6edb487120c685f63e  11985044         0               None     None
# 3  69ed5b6edb487120c685f66c  11984966         0               None     None
# 4  69ed5b6edb487120c685f66d  11984967         0               None     None
#
#   com_group_code ticker                                         news_title  \
# 0           None   None  Techcombank chia cổ tức 67%, khẳng định vị thế...
# 1           None   None   TCB: Tài liệu họp ĐHĐCĐ thường niên 2026 bổ sung
# 2           None   None  TCB: Nghị quyết HĐQT số 0193/2026 ngày 22/04/2026
# 3           None   None  TCB: Nghị quyết HĐQT thỏa thuận về đặt lệnh gi...
# 4           None   None  TCB: Nghị quyết HĐQT số 0186/2026, 0188/2026, ...
#
#   friendly_title news_sub_title  ... news_short_content news_full_content  \
# 0           None           None  ...               None              None
# 1           None           None  ...               None              None
# 2           None           None  ...               None              None
# 3           None           None  ...               None              None
# 4           None           None  ...               None              None
#
#                                       news_image_url news_small_image_url  \
# 0  https://cdn.fiingroup.vn/medialib/127379/I/202...
# 1  https://cdn.fiingroup.vn/medialib/127889/I/202...
# 2  https://cdn.fiingroup.vn/medialib/127889/I/202...
# 3  https://cdn.fiingroup.vn/medialib/127889/I/202...
# 4  https://cdn.fiingroup.vn/medialib/127889/I/202...
#
#   news_source news_source_link news_author news_keyword friendly_keyword  \
# 0        None             None        None         None             None
# 1        None             None        None         None             None
# 2        None             None        None         None             None
# 3        None             None        None         None             None
# 4        None             None        None         None             None
#
#            public_date
# 0  2026-04-25T13:17:00
# 1  2026-04-24T18:11:31
# 2  2026-04-23T17:42:37
# 3  2026-04-23T17:41:24
# 4  2026-04-23T17:39:00
#
# [5 rows x 21 columns]

# %% [markdown]
# **Lịch sự kiện công ty (Company Events)**

# %%
df = ref.company('TCB').events()
df.head()
# Out:
#                          id                        event_name_vi  \
# 0  69deda748e0e35deadec0884                   Phát hành cổ phiếu
# 1  69aa1e90f2d24c49e816ee56                 Đại hội Đồng Cổ đông
# 2  690e8e267f917761c5d19f15                        Niêm yết thêm
# 3  68fd6a8cc168044c525f93fc  Giao dịch nội bộ: Giao dịch cá nhân
# 4  68c9ffcc77867b0e0cbcb85e             Trả cổ tức bằng tiền mặt
#
#                             event_name_en ticker event_code  \
# 0                             Share Issue    TCB        ISS
# 1                  Annual General Meeting    TCB       AGME
# 2                      Additional Listing    TCB        AIS
# 3  Director Deal: Individual transactions    TCB      DDIND
# 4                           Cash Dividend    TCB        DIV
#
#                                       event_title_vi  \
# 0  Phát hành cổ phiếu - Phát hành cho CBCNV tỉ lệ...
# 1               TCB - Tổ chức ĐHĐCĐ thường niên 2026
# 2         TCB - Niêm yết bổ sung 21.388.675 cổ phiếu
# 3           Nguyễn Thu Lan - Đăng kí Mua 800,000 TCB
# 4  Trả cổ tức bằng tiền mặt - Cả năm 2024 - 1,000...
#
#                                       event_title_en        display_date1  \
# 0                      Share Issue - ESOP ratio 0.2%  2026-04-06T00:00:00
# 1                               TCB - Holds 2026 AGM  2026-04-25T00:00:00
# 2            TCB- Lists additional 21,388,675 shares  2025-11-04T00:00:00
# 3  Nguyen Thu Lan - Subscribe to Buy 800,000 TCB ...  2025-10-30T00:00:00
# 4              Cash Dividend - Year 2024 - 1,000 VND  2025-09-30T00:00:00
#
#            public_date  exercise_ratio  ...           issue_date  \
# 0  2026-04-06T00:00:00        0.002399  ...                  NaN
# 1  2026-03-06T00:00:00             NaN  ...  2026-04-25T00:00:00
# 2  2025-11-07T00:00:00             NaN  ...  2025-11-04T00:00:00
# 3  2025-11-04T00:00:00             NaN  ...                  NaN
# 4  2025-09-24T00:00:00        0.100000  ...                  NaN
#
#            record_date         exright_date           start_date  \
# 0                  NaN                  NaN                  NaN
# 1  2026-03-24T00:00:00  2026-03-23T00:00:00                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN  2025-10-30T00:00:00
# 4  2025-10-01T00:00:00  2025-09-30T00:00:00                  NaN
#
#               end_date action_type_vi action_type_en          payout_date  \
# 0                  NaN            NaN            NaN                  NaN
# 1                  NaN            NaN            NaN                  NaN
# 2                  NaN            NaN            NaN                  NaN
# 3  2025-10-31T00:00:00            Mua            Buy                  NaN
# 4                  NaN            NaN            NaN  2025-10-22T00:00:00
#
#   value_per_share listing_date
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4          1000.0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 2. Equity Domain (Danh Sách Cổ Phiếu)
#
# Tra cứu và phân loại danh sách các mã cổ phiếu đang niêm yết trên thị trường.

# %% [markdown]
# **Toàn bộ danh sách cổ phiếu (All Equities)**

# %%
df = ref.equity.list()
df.head()
# Out:
#   symbol                                 organ_name
# 0    DPP                         CTCP Dược Đồng Nai
# 1    SDA                         CTCP Simco Sông Đà
# 2    CLH                  CTCP Xi măng La Hiên VVMI
# 3    DBT                     CTCP Dược phẩm Bến Tre
# 4    DND  CTCP Đầu tư Xây dựng và Vật liệu Đồng Nai

# %% [markdown]
# **Cổ phiếu theo nhóm/rổ chỉ số (Equities by Group)**

# %%
df = ref.equity.list_by_group('VN30')
df.head()
# Out:
# 0    ACB
# 1    BID
# 2    CTG
# 3    DGC
# 4    FPT
# Name: symbol, dtype: str

# %% [markdown]
# **Cổ phiếu theo phân từng sàn (Equities by Exchange)**

# %%
df = ref.equity.list_by_exchange()
df.head()
# Out:
#   symbol                                   organ_name  \
# 0    GVT                           CTCP Giấy Việt Trì
# 1    MGC                       CTCP Địa chất mỏ - TKV
# 2    VID  CTCP Đầu tư Phát triển Thương mại Viễn Đông
# 3    GEG                            CTCP Điện Gia Lai
# 4    SWC     Tổng Công ty cổ phần Đường sông Miền Nam
#
#                                        en_organ_name exchange   type  id
# 0                Viet Tri Paper Joint Stock Company     UPCOM  stock   1
# 1     Vinacomin - Mining Geology Joint Stock Company    UPCOM  stock   1
# 2  Vien Dong Investment Development Trading Corpo...     HOSE  stock   1
# 3            Gia Lai Electricity Joint Stock Company     HOSE  stock   1
# 4          Southern Waterborne Transport Corporation    UPCOM  stock   1

# %% [markdown]
# **Cổ phiếu theo phân ngành ICB (Equities by Industry)**

# %%
df = ref.equity.list_by_industry()
df.head()
# Out:
#   symbol                         organ_name com_type_code  icb_level icb_code  \
# 0    A32                 Công ty Cổ phần 32            CT          1     3000
# 1    A32                 Công ty Cổ phần 32            CT          2     3700
# 2    A32                 Công ty Cổ phần 32            CT          3     3760
# 3    A32                 Công ty Cổ phần 32            CT          4     3765
# 4    AAA  Công ty Cổ phần Nhựa An Phát Xanh            CT          1     1000
#
#                   icb_name
# 0           Hàng Tiêu dùng
# 1  Hàng cá nhân & Gia dụng
# 2             Hàng cá nhân
# 3                 Giầy dép
# 4          Nguyên vật liệu

# %% [markdown]
# ### 3. Index Domain (Danh Sách Chỉ Số)
#
# Truy xuất danh mục rổ chỉ số, các nhóm chỉ số hỗ trợ và các mã thành phần cấu thành.

# %% [markdown]
# **Toàn bộ danh sách rổ chỉ số (All Indices)**

# %%
df = ref.index.list()
df.head()
# Out:
#   symbol   name                                        description  \
# 0   VN30   VN30  30 cổ phiếu vốn hóa lớn nhất & thanh khoản tốt...
# 1  VNMID  VNMID   Mid-Cap Index - nhóm cổ phiếu vốn hóa trung bình
# 2  VNSML  VNSML        Small-Cap Index - nhóm cổ phiếu vốn hóa nhỏ
# 3  VN100  VN100              100 cổ phiếu có vốn hoá lớn nhất HOSE
# 4  VNALL  VNALL                   Tất cả cổ phiếu trên HOSE và HNX
#
#           full_name         group  index_id  sector_id
# 0        VN30 Index  HOSE Indices         5        NaN
# 1    VNMidCap Index  HOSE Indices         6        NaN
# 2  VNSmallCap Index  HOSE Indices         7        NaN
# 3       VN100 Index  HOSE Indices         8        NaN
# 4       VNAll Index  HOSE Indices         9        NaN

# %% [markdown]
# **Các nhóm rổ chỉ số (List Index Groups)**

# %%
df = ref.index.groups()
df.head()
# Out:
#   group_name group_code       category  \
# 0       BOND       BOND     Trái phiếu
# 1         CW         CW    Chứng quyền
# 2        ETF       FUND        ETF/Quỹ
# 3   FU_INDEX        DER      Phái sinh
# 4        HNX        HNX  Sàn giao dịch
#
#                                          description
# 0  Corporate Bond - Trái phiếu doanh nghiệp niêm yết
# 1  Covered Warrant - Chứng quyền phát hành bởi cá...
# 2  Exchange-Traded Fund - Quỹ chỉ số và quỹ trao đổi
# 3                Futures - Hợp đồng tương lai chỉ số
# 4                   Sàn Giao dịch Chứng khoán Hà Nội

# %% [markdown]
# **Các thành phần trong rổ chỉ số cố định (Index Members)**

# %%
df = ref.index.members('VN30')
df.head()
# Out:
# 0    ACB
# 1    BID
# 2    CTG
# 3    DGC
# 4    FPT
# Name: symbol, dtype: str

# %% [markdown]
# **Thông tin tổng quan về một rổ chỉ số (Index Info)**

# %%
df = ref.index('VN30').info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 df = ref.index('VN30').info()
# ----> 2 df.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %% [markdown]
# ### 4. Industry Domain (Ngành Kinh Tế)
#
# Tra cứu các ngành kinh tế chuẩn ICB và phân bổ cổ phiếu trong ngành.

# %% [markdown]
# **Danh sách ngành ICB (ICB Industry List)**

# %%
df = ref.industry.list()
df.head()
# Out:
#                         icb_name               en_icb_name icb_code  level
# 0                        Dầu khí                 Oil & Gas     0001      1
# 1                        Dầu khí                 Oil & Gas     0500      2
# 2               Sản xuất Dầu khí       Oil & Gas Producers     0530      3
# 3  Sản xuất và Khai thác dầu khí  Exploration & Production     0533      4
# 4                 Tổ hợp Dầu khí      Integrated Oil & Gas     0537      4

# %% [markdown]
# **Cổ phiếu theo nhóm ngành (Stocks grouped by Sectors)**

# %%
df = ref.industry.sectors()
df.head()
# Out:
#   symbol  industry_code           industry_name
# 0    INC             28  Dịch vụ tư vấn, hỗ trợ
# 1    PPE             28  Dịch vụ tư vấn, hỗ trợ
# 2    SDC             28  Dịch vụ tư vấn, hỗ trợ
# 3    TV2             28  Dịch vụ tư vấn, hỗ trợ
# 4    TV3             28  Dịch vụ tư vấn, hỗ trợ

# %% [markdown]
# ### 5. Fund Domain (Quỹ Đầu Tư Mở)
#
# Khám phá danh sách các Quỹ mở (Mutual Funds) đang hoạt động.

# %% [markdown]
# **Danh sách quỹ đầu tư mở (List of Mutual Funds)**

# %%
df = ref.fund.list()
df.head()
# Out:
# 2026-04-28 07:32:24 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 63
# 2026-04-28 07:32:24 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 63
#   short_name                                               name     fund_type  \
# 0       DCDS                QUỸ ĐẦU TƯ CHỨNG KHOÁN NĂNG ĐỘNG DC  Quỹ cổ phiếu
# 1     SSISCA         QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI  Quỹ cổ phiếu
# 2      MAGEF  QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG MIRAE ASSET VI...  Quỹ cổ phiếu
# 3   VCBF-BCF                  QUỸ ĐẦU TƯ CỔ PHIẾU HÀNG ĐẦU VCBF  Quỹ cổ phiếu
# 4      BVFED             QUỸ ĐẦU TƯ CỔ PHIẾU NĂNG ĐỘNG BẢO VIỆT  Quỹ cổ phiếu
#
#                                      fund_owner_name  management_fee  \
# 0  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ DRAGON CAPITAL VIỆ...            1.95
# 1                       CÔNG TY TNHH QUẢN LÝ QUỸ SSI            1.75
# 2      CÔNG TY TNHH QUẢN LÝ QUỸ MIREA ASSET VIỆT NAM            1.75
# 3  CÔNG TY TNHH QUẢN LÝ QUỸ ĐẦU TƯ CHỨNG KHOÁN VI...            1.90
# 4                  CÔNG TY TNHH QUẢN LÝ QUỸ BẢO VIỆT            1.00
#
#   inception_date        nav  nav_change_previous  nav_change_last_year  \
# 0     2004-05-19  104502.12                 0.03                 -2.45
# 1     2014-09-25   45850.08                -0.26                  0.62
# 2     2019-07-22   22292.67                -0.17                  0.56
# 3     2014-08-21   44849.87                -0.21                  2.04
# 4     2014-01-07   31161.00                -0.33                  0.40
#
#    nav_change_inception  ...  nav_change_3m  nav_change_6m  nav_change_12m  \
# 0                945.02  ...          -5.63          -3.55           37.95
# 1                358.50  ...          -4.64           0.30           25.52
# 2                122.93  ...          -4.49           2.74           43.79
# 3                348.78  ...          -4.33           4.54           36.68
# 4                211.98  ...          -3.23          -0.74           39.74
#
#    nav_change_24m  nav_change_36m  nav_change_36m_annualized  nav_update_at  \
# 0           49.69           96.96                      25.35     2026-04-27
# 1           34.61           83.03                      22.32     2026-04-27
# 2           48.48           82.84                      22.28     2026-04-27
# 3           47.24           78.92                      21.40     2026-04-27
# 4           45.06           76.90                      20.94     2026-04-27
#
#   fund_id_fmarket  fund_code   vsd_fee_id
# 0              28     VFMVF1   VFMVF1N001
# 1              11     SSISCA   SSISCAN001
# 2              35      MAGEF    MAGEFN001
# 3              32    VCBFBCF  VCBFBCFN001
# 4              12      BVFED    BVFEDN001
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 6. ETF Domain (Quỹ Hoán Đổi Danh Mục)
#
# Truy cập thông tin danh sách các Quỹ Hoán Đổi Danh Mục (ETF) niêm yết.

# %% [markdown]
# **Danh sách quỹ ETF (List of ETFs)**

# %%
df = ref.etf.list()
df.head()
# Out:
# 0    E1VFVN30
# 1    FUCTVGF3
# 2    FUCTVGF4
# 3    FUCTVGF5
# 4    FUCVREIT
# Name: symbol, dtype: str

# %% [markdown]
# ### 7. Bond Domain (Trái Phiếu)
#
# Liệt kê danh sách các trái phiếu chính phủ và trái phiếu doanh nghiệp trên thị trường.

# %% [markdown]
# **Toàn bộ trái phiếu (All Bonds)**

# %%
df_all = ref.bond.list(bond_type='all')
df_all
# Out:
#        symbol        type
# 0   BAB123032   corporate
# 1   BAB124015   corporate
# 2   BAB124016   corporate
# 3   BAB124025   corporate
# 4   BAB124026   corporate
# ..        ...         ...
# 87  41B5G9000  government
# 88  41B5GC000  government
# 89  41BAG6000  government
# 90  41BAG9000  government
# 91  41BAGC000  government
#
# [92 rows x 2 columns]

# %% [markdown]
# **Trái phiếu Doanh nghiệp (Corporate Bonds)**

# %%
df_corp = ref.bond.list(bond_type='corporate')
df_corp
# Out:
# 0     BAB123032
# 1     BAB124015
# 2     BAB124016
# 3     BAB124025
# 4     BAB124026
#         ...
# 81    VIC124003
# 82    VIC124005
# 83    VND125032
# 84    VND125033
# 85    VPI124001
# Name: symbol, Length: 86, dtype: str

# %% [markdown]
# **Trái phiếu Chính phủ (Goverment Bonds)**

# %%
df_corp = ref.bond.list(bond_type='government')
df_corp
# Out:
# 0    41B5G6000
# 1    41B5G9000
# 2    41B5GC000
# 3    41BAG6000
# 4    41BAG9000
# 5    41BAGC000
# Name: symbol, dtype: str

# %% [markdown]
# ### 8. Events Domain (Sự Kiện Thị Trường)
#
# Lịch sự kiện thị trường chung như ngày giao dịch không hưởng quyền, đại hội cổ đông, thay đổi vốn, nghỉ lễ.

# %% [markdown]
# **Lịch giao dịch / Sự kiện đặc biệt toàn thị trường (Market-wide Events)**

# %%
df = ref.events.market()
df
# Out:
#           date                              event          type duration
# 0   2000-01-01                     Tết Dương Lịch       Holiday      NaN
# 1   2000-01-03  Tết Dương Lịch (Nghỉ bù/Hoán đổi)  Compensation      NaN
# 2   2000-02-04                     Tết Nguyên Đán       Holiday      NaN
# 3   2000-02-05                     Tết Nguyên Đán       Holiday      NaN
# 4   2000-02-06                     Tết Nguyên Đán       Holiday      NaN
# ..         ...                                ...           ...      ...
# 350 2026-05-01                   Quốc Tế Lao Động       Holiday      NaN
# 351 2026-08-31      Quốc Khánh (Nghỉ bù/Hoán đổi)  Compensation      NaN
# 352 2026-09-01      Quốc Khánh (Nghỉ bù/Hoán đổi)  Compensation      NaN
# 353 2026-09-02                         Quốc Khánh       Holiday      NaN
# 354 2026-11-24              Ngày Văn Hóa Việt Nam       Holiday      NaN
#
# [355 rows x 4 columns]

# %% [markdown]
# ### 10. Futures Domain (Hợp Đồng Tương Lai)
#
# Danh sách và thông tin chi tiết các hợp đồng tương lai chỉ số (Phái sinh).

# %% [markdown]
# **Liệt kê danh sách HĐTL (List of Futures Contracts)**

# %%
df = ref.futures().list()
df
# Out:
# 0     41I1G5000
# 1     41I1G6000
# 2     41I1G9000
# 3     41I1GC000
# 4     41I2G5000
# 5     41I2G6000
# 6     41I2G9000
# 7     41I2GC000
# 8     41B5G6000
# 9     41B5G9000
# 10    41B5GC000
# 11    41BAG6000
# 12    41BAG9000
# 13    41BAGC000
# Name: symbol, dtype: str

# %% [markdown]
# ### 11. Warrant Domain (Chứng Quyền Có Bảo Đảm)
#
# Danh mục niêm yết và chi tiết tham số của các Chứng quyền có bảo đảm (Covered Warrants).

# %% [markdown]
# **Liệt kê chứng quyền niêm yết (List of Covered Warrants)**

# %%
df = ref.warrant().list()
df
# Out:
# 0      CACB2510
# 1      CACB2511
# 2      CACB2514
# 3      CACB2515
# 4      CACB2516
#          ...
# 261    CVRE2525
# 262    CVRE2526
# 263    CVRE2527
# 264    CVRE2601
# 265    CVRE2602
# Name: symbol, Length: 266, dtype: str

# %% [markdown]
# ## 4. Tra cứu Thông tin & Ký hiệu Quốc tế (Global Search)
#
# Sử dụng domain `Search` để tra cứu thông tin meta-data của các tài sản đa quốc gia (Hàng hóa, Ngoại hối, Crypto).
#
# - `search.symbol()`: Quét toàn bộ metadata nội bộ của MSN nhằm lấy danh sách các instrument hợp lệ
# - `search.info()`: Cổng định tuyến mapping với MSN (Microsoft Finance) cung cấp tên đầy đủ, mô tả và sàn giao dịch cho tài sản quốc tế.

# %%
print("-- 1. Tìm symbol EUR thông qua MSN Listing --")
df_search_symbol = ref.search.symbol("EUR")
display(df_search_symbol.head())

print("-- 2. Tìm metadata chi tiết mã AAPL thông qua MSN Global Info --")
df_asset_info = ref.search.info("AAPL")
display(df_asset_info.head())
# Out:
# -- 1. Tìm symbol EUR thông qua MSN Listing --
#            symbol symbol_id exchange_name exchange_code_mic  \
# 0             EUR    aay46h       Toronto              XTSE
# 1   WIEXEBS351020    bs5ykr                 INDX_24HRS-FTSE
# 2      AWEXEBSE_T    bm931h                 INDX_24HRS-FTSE
# 3  WIEXBXKS502050    brwuz2                 INDX_24HRS-FTSE
# 4         SCEXEBS    blix77                 INDX_24HRS-FTSE
#
#                                           short_name  \
# 0                      First T AD Eu Div Idx ETF Com
# 1  FTSE World Europe Ex Eurozone Real Estate Inve...
# 2     FTSE Europe Ex EUROZONE Total Return Index EUR
# 3  FTSE World Europe Ex Eurozone Ex UK Industrial...
# 4  FTSE Europe Small Cap Ex Eurozone Price Return...
#
#                                        friendly_name  \
# 0                      First T AD Eu Div Idx ETF Com
# 1  FTSE World Europe Ex Eurozone Real Estate Inve...
# 2     FTSE Europe Ex EUROZONE Total Return Index EUR
# 3  FTSE World Europe Ex Eurozone Ex UK Industrial...
# 4  FTSE Europe Small Cap Ex Eurozone Price Return...
#
#                                             eng_name description  \
# 0     First Trust AlphaDEX European Dividend Idx ETF
# 1  FTSE World Europe Ex Eurozone Real Estate Inve...
# 2     FTSE Europe Ex EUROZONE Total Return Index EUR
# 3  FTSE World Europe Ex Eurozone Ex UK Industrial...
# 4  FTSE Europe Small Cap Ex Eurozone Price Return...
#
#                                           local_name locale
# 0     First Trust AlphaDEX European Dividend Idx ETF  en-ca
# 1  FTSE World Europe Ex Eurozone Real Estate Inve...  en-gb
# 2     FTSE Europe Ex EUROZONE Total Return Index EUR  en-gb
# 3  FTSE World Europe Ex Eurozone Ex UK Industrial...  en-gb
# 4  FTSE Europe Small Cap Ex Eurozone Price Return...  en-gb
# -- 2. Tìm metadata chi tiết mã AAPL thông qua MSN Global Info --
#   symbol symbol_id exchange_name exchange_code_mic short_name friendly_name  \
# 0   AAPL    a1mou2        NASDAQ              XNAS      Apple         Apple
# 1   AAPL    cftp8m       Toronto              XTSE      Apple         Apple
# 2   AAPL    c5wxhw         NEO-L              NEOE      Apple         Apple
# 3   AAPL    c4fc4c         Swiss              XSWX      Apple         Apple
# 4   AAPL    aainlh        Vienna              XWBO      Apple         Apple
#
#     eng_name                                        description  local_name  \
# 0  Apple Inc  Apple Inc. designs, manufactures and markets s...  APPLE INC.
# 1  Apple Inc  Apple Inc. designs, manufactures and markets s...  APPLE INC.
# 2  Apple Inc  Apple Inc. designs, manufactures and markets s...  APPLE INC.
# 3  Apple Inc  Apple Inc. designs, manufactures and markets s...  APPLE INC.
# 4  Apple Inc  Apple Inc. designs, manufactures and markets s...  APPLE INC.
#
#   locale
# 0  en-us
# 1  en-ca
# 2  en-ca
# 3  de-ch
# 4  de-at
