# %% [markdown]
# # Unified UI - Fundamental Layer (Lớp Dữ Liệu Cơ Bản) 🏦
#
# Notebook này minh hoạ cơ chế truy xuất toàn bộ các phương thức thuộc Fundamental Domain, cung cấp Báo cáo tài chính (BCTC) và Tỷ số tài chính cho các mã chứng khoán (Equity).
#
# <p>
#   <a href="https://colab.research.google.com/github/vnstock-hq/vnstock-agent-guide/blob/main/notebooks/01_unified_ui/03_Fundamental.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://codespaces.new/vnstock-hq/vnstock-agent-guide" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
# </p>
#
# ---
#
# ### Sử dụng với Jupyter Notebook (Trong IDE)
#
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# <details>
# <summary><b>💡 <i>Click để xem hướng dẫn thiết lập chi tiết</i></b></summary>
# <br>
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# **1. Kích hoạt môi trường ảo**
# (Mặc định do Vnstock Installer tạo ra, bạn có thể chỉnh lại path nếu cài ở vị trí khác)
# ```bash
# # macOS / Linux
# source ~/.venv/bin/activate
# # Windows
# ~\.venv\Scripts\activate
# ```
#
# **2. Cài đặt thư viện kết nối (`ipykernel`)**
#
# ```bash
# python -m pip install ipykernel
# ```
#
# **3. Đăng ký Kernel với Jupyter**
#
# ```bash
# python -m ipykernel install --user --name=vnstock-venv --display-name "Python (Vnstock)"
# ```
#
# **4. Chọn Kernel trong IDE**
#
# Nhìn góc trên bên phải Notebook, click vào tên Kernel hiện tại (vd: *Select Kernel* hoặc *Python 3.x.x*).
# Chọn **Python (Vnstock)** từ danh sách. (Tải lại cửa sổ nếu chưa thấy bằng tổ hợp phím `Ctrl`/`Cmd` + `Shift` + `P` sau đó tìm lệnh `Developer: Reload Window`).
# </details>

# %%
from vnstock import Fundamental
from IPython.display import display

# Initialize Fundamental layer
fun = Fundamental()

# %% [markdown]
# ### Cấu trúc Gọi Hàm (Calling Conventions)
#
# Mô đun Fundamental hỗ trợ 2 dạng cú pháp linh hoạt (Proxy chaining):
# 1. `fun.equity("MÃ").method()` - Hướng đối tượng đối với một mã.
# 2. `fun.equity.method("MÃ")` - Dạng hàm tiện ích (Utility function).

# %% [markdown]
# ### 1. Income Statement (Báo Cáo Kết Quả Kinh Doanh)
#
# Báo cáo thu nhập, doanh thu, chi phí, lợi nhuận hoạt động và lợi nhuận ròng qua các kỳ.

# %% [markdown]
# **Lấy báo cáo kết quả KD ngân hàng TCB (Income Statement - TCB)**

# %%
df = fun.equity("TCB").income_statement(limit=4)
df
# Out:
#                                                  item  \
# 0      1. Thu nhập lãi và các khoản thu nhập tương tự
# 1              2. Chi phí lãi và các chi phí tương tự
# 2                               I. Thu nhập lãi thuần
# 3                    3. Thu nhập từ hoạt động dịch vụ
# 4                        4. Chi phí hoạt động dịch vụ
# 5               II. Lãi/lỗ thuần từ hoạt động dịch vụ
# 6   III. Lãi/lỗ thuần từ hoạt động kinh doanh ngoạ...
# 7   IV. Lãi/lỗ thuần từ mua bán chứng khoán kinh d...
# 8       V. Lãi/lỗ thuần từ mua bán chứng khoán đầu tư
# 9                       5. Thu nhập từ hoạt động khác
# 10                          6. Chi phí hoạt động khác
# 11                 VI. Lãi/lỗ thuần từ hoạt động khác
# 12              VII. Thu nhập từ góp vốn, mua cổ phần
# 13                            VIII. Chi phí hoạt động
# 14  IX. Lợi nhuận thuần từ hoạt động kinh doanh tr...
# 15                X. Chi phí dự phòng rủi ro tín dụng
# 16               XI. Tổng lợi nhuận trước thuế (IX-X)
# 17                     7. Chi phí thuế TNDN hiện hành
# 18                      8. Chi phí thuế TNDN hoãn lại
# 19                             XII. Chi phí thuế TNDN
# 20                  XIII. Lợi nhuận sau thuế (XI-XII)
# 21                  XIV. Lợi ích của cổ đông thiểu số
# 22  XV. Lợi nhuận sau thuế của cổ đông của Ngân hà...
# 23              Lãi cơ bản trên cổ phiếu (BCTC) (VNÐ)
#
#                                               item_id          2025  \
# 0              n_1.interest_income_and_similar_income  6.801745e+10
# 1           n_2.interest_expense_and_similar_expenses  2.986236e+10
# 2                               i.net_interest_income  3.815509e+10
# 3                       n_3.fee_and_commission_income  1.252696e+10
# 4                     n_4.fee_and_commission_expenses  3.754968e+09
# 5                    ii.net_fee_and_commission_income  8.771995e+09
# 6   iii.net_gain_loss_from_foreign_currencies_and_...  1.642201e+09
# 7            iv.net_gain_loss_from_trading_securities  5.197400e+07
# 8          v.net_gain_loss_from_investment_securities  2.846321e+09
# 9                                    n_5.other_income  6.426334e+09
# 10                                 n_6.other_expenses  4.541992e+09
# 11                                vi.net_other_income  1.884342e+09
# 12  vii.income_from_capital_contribution_and_long_...  3.920100e+07
# 13                            viii.operating_expenses  1.643243e+10
# 14  ix.operating_profit_before_provision_for_credi...  3.695869e+10
# 15                      x.provision_for_credit_losses  4.420625e+09
# 16                               xi.profit_before_tax  3.253807e+10
# 17          n_7.current_corporate_income_tax_expenses  6.544225e+09
# 18                   n_8.deferred_income_tax_expenses  3.936900e+07
# 19                           xii.corporate_income_tax  6.583594e+09
# 20                          xiii.net_profit_after_tax  2.595447e+10
# 21                              xiv.minority_interest  6.642420e+08
# 22  xv.net_profit_atttributable_to_the_equity_hold...  2.529023e+10
# 23                              earning_per_share_vnd  3.572000e+03
#
#             2024          2023          2022
# 0   6.008946e+10  5.670776e+10  4.475264e+10
# 1   2.458150e+10  2.901664e+10  1.446286e+10
# 2   3.550796e+10  2.769112e+10  3.028978e+10
# 3   1.096164e+10  1.137808e+10  1.084034e+10
# 4   2.919394e+09  2.663188e+09  2.312843e+09
# 5   8.042248e+09  8.714897e+09  8.527494e+09
# 6   5.925560e+08  1.957500e+08 -2.750630e+08
# 7   8.130100e+07  6.462000e+07 -2.418450e+08
# 8   2.359057e+09  9.258330e+08  4.255530e+08
# 9   9.324928e+09  6.459694e+09  4.499949e+09
# 10  8.982217e+09  4.025578e+09  2.332574e+09
# 11  3.427110e+08  2.434116e+09  2.167375e+09
# 12  6.456100e+07  3.475600e+07  8.791000e+06
# 13  1.536974e+10  1.325180e+10  1.339802e+10
# 14  3.162066e+10  2.680930e+10  2.750406e+10
# 15  4.082294e+09  3.921068e+09  1.936294e+09
# 16  2.753837e+10  2.288823e+10  2.556777e+10
# 17  5.787711e+09  4.706721e+09  5.174932e+09
# 18 -9.447000e+06 -9.359000e+06 -4.359000e+07
# 19  5.778264e+09  4.697362e+09  5.131342e+09
# 20  2.176010e+10  1.819087e+10  2.043643e+10
# 21  2.371760e+08  1.870640e+08  2.860490e+08
# 22  2.152293e+10  1.800380e+10  2.015038e+10
# 23  3.049000e+03  5.104000e+03  5.725000e+03

# %% [markdown]
# ### 2. Balance Sheet (Bảng Cân Đối Kế Toán)
#
# Số liệu phản ánh tài sản, nợ phải trả, vốn chủ sở hữu qua các kỳ báo cáo.

# %% [markdown]
# **Lấy cân đối kế toán doanh nghiệp VIC (Balance Sheet - VIC)**

# %%
df = fun.equity('VIC').balance_sheet(period='quarter')
df.head()
# Out:
# <div style='background-color: #e3f2fd; border-left: 4px solid #2196f3; padding: 12px 16px; margin: 12px 0; border-radius: 4px; font-size: 13px;'><strong>ℹ️  Phiên bản cộng đồng</strong><br>Báo cáo tài chính được giới hạn tối đa <strong>8 kỳ</strong> để minh hoạ thuật toán. Để truy cập đầy đủ tất cả các kỳ báo cáo, vui lòng <a href='https://vnstocks.com/insiders-program' target='_blank'>tham gia gói thành viên tài trợ dự án</a>.</div>
#                                     item                      item_id  \
# 0                               TÀI SẢN                        assets
# 1                    A. TÀI SẢN NGẮN HẠN          a.short_term_assets
# 2  I. Tiền và các khoản tương đương tiền  i.cash_and_cash_equivalents
# 3                                1. Tiền                     n_1.cash
# 4          2. Các khoản tương đương tiền         n_2.cash_equivalents
#
#         2025-Q4       2025-Q3       2025-Q2       2025-Q1
# 0           NaN           NaN           NaN           NaN
# 1  6.609248e+11  5.906419e+11  5.284755e+11  3.721839e+11
# 2  7.352650e+10  7.215072e+10  7.476002e+10  3.249194e+10
# 3  3.597365e+10  5.245198e+10  4.708552e+10  3.077660e+10
# 4  3.755284e+10  1.969874e+10  2.767450e+10  1.715343e+09

# %% [markdown]
# ### 3. Cash Flow (Báo Cáo Lưu Chuyển Tiền Tệ)
#
# Theo dõi dòng tiền từ hoạt động kinh doanh, đầu tư và tài chính.

# %% [markdown]
# **Lưu chuyển tiền tệ của VNM (Cash Flow - VNM)**

# %%
df = fun.equity("VNM").cash_flow(period='quarter')
df
# Out:
# <div style='background-color: #e3f2fd; border-left: 4px solid #2196f3; padding: 12px 16px; margin: 12px 0; border-radius: 4px; font-size: 13px;'><strong>ℹ️  Phiên bản cộng đồng</strong><br>Báo cáo tài chính được giới hạn tối đa <strong>8 kỳ</strong> để minh hoạ thuật toán. Để truy cập đầy đủ tất cả các kỳ báo cáo, vui lòng <a href='https://vnstocks.com/insiders-program' target='_blank'>tham gia gói thành viên tài trợ dự án</a>.</div>
#                                                  item  \
# 0          I. Lưu chuyển tiền từ hoạt động kinh doanh
# 1                             1. Lợi nhuận trước thuế
# 2                         2. Điều chỉnh cho các khoản
# 3                              Khấu hao TSCĐ và BĐSĐT
# 4                                  Các khoản dự phòng
# 5   Lãi, lỗ chênh lệch tỷ giá hối đoái do đánh giá...
# 6              Lãi, lỗ từ hoạt động đầu tư, tài chính
# 7                                      Chi phí đi vay
# 8                            Lãi, lỗ từ thanh lý TSCĐ
# 9                          Thu nhập lãi vay và cổ tức
# 10                         Phân bổ lợi thế thương mại
# 11                         Các khoản điều chỉnh khác
# 12  3. Lợi nhuận từ hoạt động kinh doanh trước tha...
# 13                      Tăng, giảm các khoản phải thu
# 14                            Tăng, giảm hàng tồn kho
# 15  Tăng, giảm các khoản phải trả (không kể lãi va...
# 16                     Tăng, giảm chi phí chờ phân bổ
# 17                  Tăng, giảm chứng khoán kinh doanh
# 18                              Chi phí đi vay đã trả
# 19                  Thuế thu nhập doanh nghiệp đã nộp
# 20              Tiền thu khác từ hoạt động kinh doanh
# 21             Tiền chi khác cho hoạt động kinh doanh
# 22      Lưu chuyển tiền thuần từ hoạt động kinh doanh
# 23            II. Lưu chuyển tiền từ hoạt động đầu tư
# 24  1. Tiền chi để mua sắm, xây dựng TSCĐ và các t...
# 25  2. Tiền thu từ thanh lý, nhượng bán TSCĐ và cá...
# 26  3. Tiền chi cho vay, mua các công cụ nợ của đơ...
# 27  4. Tiền thu hồi cho vay, bán lại các công cụ n...
# 28         5. Tiền chi đầu tư góp vốn vào đơn vị khác
# 29     6. Tiền thu hồi đầu tư góp vốn vào đơn vị khác
# 30  7. Tiền thu lãi cho vay, cổ tức và lợi nhuận đ...
# 31          8. Tăng giảm tiền gửi ngân hàng có kỳ hạn
# 32  9. Mua lại khoản góp vốn của cổ đông thiểu số ...
# 33              10. Tiền thu khác từ hoạt động đầu tư
# 34             11. Tiền chi khác cho hoạt động đầu tư
# 35          Lưu chuyển tiền thuần từ hoạt động đầu tư
# 36        III. Lưu chuyển tiền từ hoạt động tài chính
# 37  1. Tiền thu từ phát hành cổ phiếu, nhận vốn gó...
# 38  2. Tiền trả lại vốn góp cho các chủ sở hữu, mu...
# 39                              3. Tiền thu từ đi vay
# 40                             4. Tiền trả nợ gốc vay
# 41                  5. Tiền trả nợ gốc thuê tài chính
# 42         6. Cổ tức, lợi nhuận đã trả cho chủ sở hữu
# 43            7. Tiền thu khác từ hoạt động tài chính
# 44           8. Tiền chi khác cho hoạt động tài chính
# 45       Lưu chuyển tiền thuần từ hoạt động tài chính
# 46                     Lưu chuyển tiền thuần trong kỳ
# 47                    Tiền và tương đương tiền đầu kỳ
# 48  Ảnh hưởng của thay đổi tỷ giá hối đoái quy đổi...
# 49                   Tiền và tương đương tiền cuối kỳ
#
#                                               item_id       2025-Q1
# 0              i_cash_flows_from_operating_activities           NaN
# 1                               n_1.profit_before_tax  1.951296e+09
# 2                                 n_2_adjustments_for           NaN
# 3   depreciation_of_fixed_assets_and_investment_pr...  5.117912e+08
# 4                   reversal_of_provisions_provisions  2.485757e+06
# 5   foreign_exchange_gain_loss_from_revaluation_of...  4.698502e+06
# 6   gains_losses_from_investing_and_financing_acti... -3.431853e+08
# 7                                     borrowing_costs  7.515521e+07
# 8           loss_profits_from_disposal_of_fixed_asset           NaN
# 9                       interest_income_and_dividends           NaN
# 10                             allocation_of_goodwill  6.081978e+07
# 11                                  other_adjustments           NaN
# 12  n_3.operating_profit_before_changes_in_working...  2.263061e+09
# 13                   increase_decrease_in_receivables  9.159227e+08
# 14                   increase_decrease_in_inventories -1.409386e+09
# 15  increase_decrease_in_payables_excluding_intere... -4.298664e+08
# 16             increase_decrease_in_deferred_expenses -6.194934e+07
# 17           changes_in_available_for_sale_securities           NaN
# 18                             interest_expenses_paid -5.888010e+07
# 19                          corporate_income_tax_paid -9.318631e+08
# 20           other_receipts_from_operating_activities           NaN
# 21            other_payments_for_operating_activities -4.117540e+08
# 22           net_cash_flows_from_operating_activities -1.247148e+08
# 23            ii_cash_flows_from_investing_activities           NaN
# 24  n_1.payment_for_fixed_assets_constructions_and... -4.170184e+08
# 25  n_2.receipts_from_disposal_of_fixed_assets_and...  2.569754e+07
# 26  n_3.loans_purchases_of_other_entities_debt_ins...           NaN
# 27  n_4.receipts_from_loan_repayments_sale_of_othe...  7.748297e+08
# 28      n_5.payments_for_investment_in_other_entities           NaN
# 29    n_6.collections_on_investment_in_other_entities  9.833160e+05
# 30         n_7.dividends_interest_and_profit_received  1.579818e+08
# 31              n_8.increase_decrease_in_term_deposit           NaN
# 32   n_9.purchases_of_minority_shares_of_subsidiaries           NaN
# 33      n_10.other_receipts_from_investing_activities           NaN
# 34       n_11.other_payments_for_investing_activities           NaN
# 35           net_cash_flows_from_investing_activities  5.424740e+08
# 36           iii_cash_flows_from_financing_activities           NaN
# 37  n_1.receipts_from_equity_issue_and_owners_capi...           NaN
# 38  n_2.cash_paid_to_repurchased_or_redeem_the_ent...           NaN
# 39                       n_3.proceeds_from_borrowings  4.902421e+09
# 40                           n_4.principal_repayments -3.963677e+09
# 41                  n_5.repayment_of_financial_leases -1.044978e+09
# 42   n_6.dividends_paid_profits_distributed_to_owners           NaN
# 43       n_7.other_receipts_from_financing_activities           NaN
# 44        n_8.other_payments_for_financing_activities           NaN
# 45           net_cash_flows_from_financing_activities -1.062339e+08
# 46                   net_cash_flows_during_the_period  3.115253e+08
# 47  cash_and_cash_equivalents_at_beginning_of_the_...  2.225944e+09
# 48  exchange_difference_due_to_re_valuation_of_end...  5.553320e+05
# 49     cash_and_cash_equivalents_at_end_of_the_period  2.538024e+09

# %% [markdown]
# ### 4. Financial Ratio (Tỷ Số Tài Chính)
#
# Tổng hợp các tỷ số quan trọng như P/E, P/B, ROA, ROE, Tỷ lệ vay nợ (Debt/Equity), v.v.

# %% [markdown]
# **Tỷ số tài chính của HPG (Financial Ratios - HPG)**

# %%
df = fun.equity("HPG").ratio(period='quarter')
df
# Out:
#                                                  item  \
# 0   Thu nhập trên mỗi cổ phần của 4 quý gần nhất (...
# 1                 Giá trị sổ sách của cổ phiếu (BVPS)
# 2           Chỉ số giá thị trường trên thu nhập (P/E)
# 3    Chỉ số giá thị trường trên giá trị sổ sách (P/B)
# 4    Chỉ số giá thị trường trên doanh thu thuần (P/S)
# 5                                      Tỷ suất cổ tức
# 6                                                Beta
# 7   Giá trị doanh nghiệp trên lợi nhuận trước thuế...
# 8   Giá trị doanh nghiệp trên lợi nhuận trước thuế...
# 9                          Tỷ suất lợi nhuận gộp biên
# 10                                     Tỷ lệ lãi EBIT
# 11                                   Tỷ lệ lãi EBITDA
# 12              Tỷ suất sinh lợi trên doanh thu thuần
# 13  Tỷ suất lợi nhuận trên vốn chủ sở hữu bình quâ...
# 14  Tỷ suất sinh lợi trên vốn dài hạn bình quân (R...
# 15  Tỷ suất sinh lợi trên tổng tài sản bình quân (...
# 16                       ROE bình quân 4 quý gần nhất
# 17                       ROA bình quân 4 quý gần nhất
# 18                       Tăng trưởng  doanh thu thuần
# 19                         Tăng trưởng  lợi nhuận gộp
# 20                  Tăng trưởng lợi nhuận trước thuế
# 21   Tăng trưởng lợi nhuận sau thuế của CĐ công ty mẹ
# 22                           Tăng trưởng tổng tài sản
# 23                             Tăng trưởng nợ dài hạn
# 24                            Tăng trưởng nợ phải trả
# 25                         Tăng trưởng vốn chủ sở hữu
# 26                            Tăng trưởng vốn điều lệ
# 27                     Tỷ số thanh toán bằng tiền mặt
# 28                             Tỷ số thanh toán nhanh
# 29  Tỷ số thanh toán nhanh  (Đã loại trừ HTK, Phải...
# 30              Tỷ số thanh toán hiện hành (ngắn hạn)
# 31                        Khả năng thanh toán lãi vay
# 32                      Vòng quay phải thu khách hàng
# 33            Thời gian thu tiền khách hàng bình quân
# 34                             Vòng quay hàng tồn kho
# 35                        Thời gian tồn kho bình quân
# 36                    Vòng quay phải trả nhà cung cấp
# 37            Thời gian trả tiền khách hàng bình quân
# 38  Vòng quay tài sản cố định (Hiệu suất sử dụng t...
# 39  Vòng quay tổng tài sản (Hiệu suất sử dụng toàn...
# 40                           Vòng quay vốn chủ sở hữu
# 41            Tỷ số Nợ ngắn hạn trên Tổng nợ phải trả
# 42                     Tỷ số Nợ vay trên Tổng tài sản
# 43                         Tỷ số Nợ trên Tổng tài sản
# 44             Tỷ số Vốn chủ sở hữu trên Tổng tài sản
# 45              Tỷ số Nợ ngắn hạn trên Vốn chủ sở hữu
# 46                   Tỷ số Nợ vay trên Vốn chủ sở hữu
# 47                       Tỷ số Nợ trên Vốn chủ sở hữu
# 48          Tỷ số dòng tiền HĐKD trên doanh thu thuần
# 49     Khả năng chi trả nợ ngắn hạn từ dòng tiền HĐKD
# 50  Khả năng chi trả nợ ngắn hạn từ lưu chuyển tiề...
# 51       Tỷ lệ dồn tích (Phương pháp Cân đối kế toán)
# 52             Tỷ lệ dồn tích (Phương pháp Dòng tiền)
# 53                Dòng tiền từ HĐKD trên Tổng tài sản
# 54              Dòng tiền từ HĐKD trên Vốn chủ sở hữu
# 55     Dòng tiền từ HĐKD trên Lợi nhuận thuần từ HĐKD
# 56           Khả năng thanh toán nợ từ dòng tiền HĐKD
# 57           Dòng tiền từ HĐKD trên mỗi cổ phần (CPS)
#
#                                               item_id   2025-Q4   2025-Q3  \
# 0                                        trailing_eps   2203.18   2157.16
# 1                           book_value_per_share_bvps  17096.00  16613.00
# 2                                                 p_e     11.98     13.05
# 3                                                 p_b      1.54      1.69
# 4                                                 p_s      4.39      5.93
# 5                                      dividend_yield      0.00      0.00
# 6                                                beta      1.07      1.14
# 7                                             ev_ebit     49.44     56.22
# 8                                           ev_ebitda     20.84     25.98
# 9                                 gross_profit_margin     13.85     16.72
# 10                                        ebit_margin     12.64     14.94
# 11                                 ebitda_net_revenue     18.53     20.57
# 12                                  net_profit_margin      8.42     11.02
# 13                                                roe      2.98      3.19
# 14                    return_on_capital_employed_roce      3.57      3.41
# 15                                                roa      1.53      1.63
# 16                                      roe_trailling     12.51     12.02
# 17                                      roa_trailling      6.34      6.11
# 18                                        net_revenue     33.88      7.22
# 19                                       gross_profit     46.55     28.66
# 20                                  profit_before_tax     39.96     35.63
# 21  profit_after_tax_for_shareholders_of_the_paren...     37.56     31.93
# 22                                       total_assets     14.89     16.46
# 23                              long_term_liabilities     -5.38     15.94
# 24                                        liabilities     15.35     19.12
# 25                                      owners_equity     14.46     14.08
# 26                                    charter_capital     20.00     20.00
# 27                                         cash_ratio      0.09      0.11
# 28                                        quick_ratio      0.54      0.60
# 29  quick_ratio_except_inventories_short_term_rece...      0.29      0.34
# 30                                   short_term_ratio      1.10      1.15
# 31                                  interest_coverage      4.72      6.70
# 32                               receivables_turnover      4.87      4.50
# 33                          days_of_sales_outstanding     74.99     81.07
# 34                                 inventory_turnover      0.81      0.64
# 35                          days_of_inventory_on_hand    451.67    568.67
# 36                                  payables_turnover      2.68      2.24
# 37                         number_of_days_of_payables    136.32    162.98
# 38                               fixed_asset_turnover      0.39      0.43
# 39                               total_asset_turnover      0.18      0.15
# 40                                    equity_turnover      0.36      0.29
# 41        short_term_liabilities_to_total_liabilities     74.35     70.09
# 42                                     debt_to_assets     35.74     39.34
# 43                              liabilities_to_assets     49.12     48.20
# 44                                   equity_to_assets     50.88     51.80
# 45                   short_term_liabilities_to_equity     71.79     65.22
# 46                                     debt_to_equity     70.24     75.94
# 47                              liabilities_to_equity     96.56     93.05
# 48                                   accrual_ratio_cf      0.00      0.00
# 49                                     cash_to_income      0.00      0.00
# 50              net_cash_flows_short_term_liabilities      0.00      0.00
# 51                 accrual_ratio_balance_sheet_method      0.00      0.00
# 52                     accrual_ratio_cash_flow_method      0.00      0.00
# 53                              cash_return_to_assets      0.00      0.00
# 54                              cash_return_on_equity      0.00      0.00
# 55                                   cash_to_income_2      0.00      0.00
# 56                                      debt_coverage      0.00      0.00
# 57                            cash_flow_per_share_cps      0.00      0.00
#
#      2025-Q2   2025-Q1
# 0    2099.79   1983.64
# 1   19130.00  18448.00
# 2      10.81     13.49
# 3       1.19      1.45
# 4       4.04      4.55
# 5       0.00      0.00
# 6       1.11      1.21
# 7      41.75     56.64
# 8      19.86     40.36
# 9      18.35     14.42
# 10     15.07     11.87
# 11     19.35     16.66
# 12     11.88      8.90
# 13      3.54      2.88
# 14      3.52      2.97
# 15      1.81      1.48
# 16     11.55     11.05
# 17      5.92      5.74
# 18     -9.21     21.94
# 19     25.58     30.58
# 20     33.19     17.74
# 21     28.24     16.50
# 22     17.24     13.33
# 23     37.21     97.43
# 24     22.40     15.11
# 25     12.59     11.71
# 26      0.00     10.00
# 27      0.12      0.10
# 28      0.56      0.55
# 29      0.33      0.31
# 30      1.13      1.15
# 31     12.32      7.12
# 32      4.60      6.40
# 33     79.28     57.03
# 34      0.61      0.69
# 35    594.15    527.84
# 36      1.94      2.49
# 37    188.33    146.35
# 38      0.48      0.49
# 39      0.15      0.17
# 40      0.30      0.32
# 41     72.09     69.72
# 42     37.40     38.91
# 43     49.49     48.44
# 44     50.51     51.56
# 45     70.62     65.51
# 46     74.04     75.46
# 47     97.96     93.96
# 48      0.00     -7.38
# 49      0.00     -3.59
# 50      0.00      0.74
# 51      0.00      0.00
# 52      0.00      0.00
# 53      0.00     -1.21
# 54      0.00     -2.35
# 55      0.00    -72.98
# 56      0.00     -2.51
# 57      0.00   -434.31
